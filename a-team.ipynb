# %%
# %matplotlib inline

# %%
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ↑はopencv２をインポートしています

# %%
# read an image
img = cv2.imread('idon.jpg')

# %%
print(img)
# Out:
# [[[226 226 226]
#   [226 226 226]
#   [226 226 226]
#   ...,
#   [225 225 225]
#   [224 224 224]
#   [247 247 247]]
#
#  [[226 226 226]
#   [226 226 226]
#   [226 226 226]
#   ...,
#   [225 225 225]
#   [224 224 224]
#   [247 247 247]]
#
#  [[226 226 226]
#   [226 226 226]
#   [226 226 226]
#   ...,
#   [225 225 225]
#   [224 224 224]
#   [247 247 247]]
#
#  ...,
#  [[219 214 215]
#   [219 214 215]
#   [219 214 215]
#   ...,
#   [216 214 214]
#   [214 212 212]
#   [247 245 245]]
#
#  [[219 214 215]
#   [219 214 215]
#   [219 214 215]
#   ...,
#   [216 214 214]
#   [214 212 212]
#   [247 245 245]]
#
#  [[219 214 215]
#   [219 214 215]
#   [219 214 215]
#   ...,
#   [217 215 215]
#   [214 212 212]
#   [247 245 245]]]

# %%
plt.imshow(img)

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
sets = set([1,2,3,4,1,2])
tupple = (1,2,3)
list = [1, 2, 3]
dict = {'key':'value'}

# %%
sets
# Out:
# {1, 2, 3, 4}

# %%
tupple[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-13a6c396fbe6> in <module>()
# ----> 1 tupple[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(10 // 4)
# Out:
# 2
